# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,10,100)

# %%
plt.plot(x,x, label='linear')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
x = [345,345,2,65,87,567,886,534,54,4,4]
#print(len(x))
y = [456,345,75,123,56,23,865,45,756,34,8]
#print(len(y))

# %%
plt.scatter(x,y)
plt.show()
